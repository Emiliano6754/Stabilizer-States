# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
n_qubits = 8
C40_fact = n_qubits * (3 * n_qubits - 3)
C42_fact = (6 * n_qubits - 8)
Sx, Sx2, Sx3, Sx4 = np.genfromtxt("C:/dev/StabilizerStates/data/graphs/Sx_exp_q"+str(n_qubits)+".txt", delimiter = ",", dtype = int, usecols=(0,1,2,3), unpack = True)

# %%
fig = plt.figure(6754)
ax = fig.subplots()
ax.scatter(Sx2, Sx3)

# %%
fig = plt.figure(6754)
ax = fig.subplots()
ax.scatter(Sx2, Sx4)
x = np.arange(0, np.max(Sx2))
pred = C40_fact + C42_fact * (x - n_qubits)
ax.plot(x, pred)
